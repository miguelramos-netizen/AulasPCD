# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelramos-netizen/AulasPCD/blob/main/Aula05pcd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open("sample_data/README.md")

conteudo = f.readlines()

f.close

print(conteudo)

for linha in conteudo:
  print (linha)
# Out:
# ['This directory includes a few sample datasets to get you started.\n', '\n', '*   `california_housing_data*.csv` is California housing data from the 1990 US\n', '    Census; more information is available at:\n', '    https://docs.google.com/document/d/e/2PACX-1vRhYtsvc5eOR2FWNCwaBiKL6suIOrxJig8LcSBbmCbyYsayia_DvPOOBlXZ4CAlQ5nlDD8kTaIDRwrN/pub\n', '\n', '*   `mnist_*.csv` is a small sample of the\n', '    [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is\n', '    described at: http://yann.lecun.com/exdb/mnist/\n', '\n', '*   `anscombe.json` contains a copy of\n', "    [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it\n", '    was originally described in\n', '\n', "    Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American\n", '    Statistician. 27 (1): 17-21. JSTOR 2682899.\n', '\n', '    and our copy was prepared by the\n', '    [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e354998
# ...

# %%
# !git --version
# !git config --global user.name "Miguel"
# !git config --global user.email "miguel.ramos@sou.unijui.edu.br"
# !git config --global init.defaultBranch main
# !git config --global --list

# !git clone https://github.com/miguelramos-netizen/AulasP_CD.git
# Out:
# git version 2.34.1
# user.name=Miguel
# user.email=miguel.ramos@sou.unijui.edu.br
# init.defaultbranch=main
# fatal: destination path 'AulasP_CD' already exists and is not an empty directory.
